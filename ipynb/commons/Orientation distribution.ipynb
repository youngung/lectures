# %% [markdown]
# ## Orientation distribution and pole figures
# This notebook is to describe the orientation distribution and pole figures in general
#
# - Youngung Jeong @ CWNU

# %%
# %pylab inline
import scipy
import scipy.stats
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Univariate distribution

# %% [markdown]
# - [Normal distribution](https://en.wikipedia.org/wiki/Normal_distribution)

# %%
x=np.linspace(-10,10,1000)
y=scipy.stats.norm.pdf(x)
fig=plt.figure(figsize=(3,3))
ax=gca()
ax.plot(x,y)
ax.set_xlabel('Variable x')
ax.set_ylabel('Probability distribution')
ax.set_title('Normal distribution')
# Out:
# Text(0.5,1,'Normal distribution')

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
ax = fig.gca(projection='3d')
#X, Y, Z = axes3d.get_test_data(0.05)

x = np.linspace(-4, 4, 400)
y = np.linspace(-4, 4, 400)
X, Y = np.meshgrid(x, y)
pos = np.dstack((X, Y))
mu = np.array([0, 0])
cov = np.array([[1, 0],[0, 1]])
rv = multivariate_normal(mu, cov)
Z = rv.pdf(pos)


ax.set_xlabel('X')
#ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
#ax.set_ylim(-40, 40)
ax.set_zlabel('f(x,y) probability')
#ax.set_zlim(-100, 100)
# plt.show()




#ax.plot_surface(X, Y, Z, rstride=5, cstride=5, alpha=0.5,cmap=cm.viridis)
#fig.savefig('2d_distr1.png')
#cset = ax.contourf(X, Y, Z, zdir='x', offset=-4, cmap=cm.viridis)
#fig.savefig('2d_distr2.png')
#cset = ax.contourf(X, Y, Z, zdir='y', offset=4, cmap=cm.viridis)
#fig.savefig('2d_distr3.png')
cset = ax.contourf(X, Y, Z, zdir='z', offset=0, cmap=cm.viridis)
fig.savefig('2d_distr4.png')

# %%
# !open ./
