# %%
import numpy as np

# %%
ls ../data/
# Out:
# matrix
# matrix_01.csv
# matrix_01.csv~
# matrix_01.txt
# matrix_01.txt~
# matrix_02.txt
# matrix_03.txt
# score_record_2017_MF_final_analysis.txt*

# %%
``
