# %%
# !pip install ipympl
# %matplotlib widget
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Collecting ipympl
#   Downloading ipympl-0.9.7-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: ipython<10 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipympl) (8.22.2)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipympl) (8.1.2)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipympl) (3.8.3)
# Requirement already satisfied: numpy in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipympl) (1.26.4)
# Requirement already satisfied: pillow in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipympl) (10.2.0)
# Requirement already satisfied: traitlets<6 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipympl) (5.14.1)
# Requirement already satisfied: decorator in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipython<10->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipython<10->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipython<10->ipympl) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipython<10->ipympl) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipython<10->ipympl) (2.17.2)
# Requirement already satisfied: stack-data in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from stack-data->ipython<10->ipympl) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from stack-data->ipython<10->ipympl) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from stack-data->ipython<10->ipympl) (0.2.2)
# Downloading ipympl-0.9.7-py3-none-any.whl (515 kB)
# Installing collected packages: ipympl
# Successfully installed ipympl-0.9.7

# %% [markdown]
# # Normal distribution

# %%
xs=np.random.normal(0,3,100000)
rst=plt.hist(xs,bins=50)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Create noisy data

# %%
import numpy as np
import matplotlib.pyplot as plt

# example data with noise
xs = np.linspace(0, 10, 10)
a=2.5
b=5
y_true = a * xs + b
## artificial noise added.
noise = np.random.normal(0, 50, size=xs.shape) ## 정규분포 mean:0, std: 3
ys = y_true + noise
plt.plot(xs,y_true)
plt.plot(xs,ys,'o')

# %%
plt.plot(xs,ys,'ro',label='Data with noise')
#plt.plot(xs,y_true,'k-',label='True data')

tilde_a=2
tilde_b=5

epsilon=np.zeros(xs.shape)
for i, x in enumerate(xs):
    y=x*tilde_a+tilde_b
    epsilon[i]=y-ys[i]
    plt.plot([x,x],[ys[i],y],'-')
plt.plot(xs,tilde_a*xs+tilde_b,'m--',label='manual fit')
print(f'residual: {(epsilon**2).sum()}')
plt.legend()

## least square
matrix=np.zeros((2,2))
matrix[0,0]=(xs**2).sum()
matrix[0,1]=xs.sum()
matrix[1,0]=xs.sum()
matrix[1,1]=len(xs)
#print(matrix)
c=np.zeros(2)
c[0]=(xs*ys).sum()
c[1]=ys.sum()
a_lsq,b_lsq=np.linalg.inv(matrix)@c ## m^{-1} . c
ys_opti=xs*a_lsq+b_lsq
plt.plot(xs,ys_opti,label='Least square')
print('a and a_lsq:',a,a_lsq)
print('b and b_lsq:',b,b_lsq)
plt.plot(xs,y_true,label='actual data without noise')
plt.legend()
#plt.plot([x*1.1,x*1.1],[-abs(epsilon).sum()*0.5,abs(epsilon).sum()*0.5],'--b',label='total residual')
# Out:
# residual: 22641.743606989992
# a and a_lsq: 2.5 9.564259905126288
# b and b_lsq: 5 -35.296920569162616

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 (y는 X와 독립적으로 선택)
x = np.linspace(0, 10, 10)
y = 2.5 * x + 5 + np.random.normal(0, 3, size=x.shape)

# 디자인 행렬
X = np.vstack([x, np.ones(len(x))]).T

# 최소자승 해
theta = np.linalg.inv(X.T @ X) @ (X.T @ y)
y_fit = X @ theta

# 잔차 벡터 (residual)
residual = y - y_fit

plt.figure(figsize=(8,6))
plt.scatter(x, y, label="data (y)", color="red")
plt.plot(x, y_fit, label="Least sq. line (Xθ)", color="blue")

# 잔차 시각화 (y점에서 직선까지 수직선)
for xi, yi, yfi in zip(x, y, y_fit):
    plt.plot([xi, xi], [yi, yfi], color="gray", linestyle="--")

plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Least Squares: Residuals as Orthogonal Projection")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# (1) 데이터 생성 (z = 2x + 3y + 5 + noise)
np.random.seed(0)
x = np.random.rand(30) * 10
y = np.random.rand(30) * 10
z_true = 2*x + 3*y + 5
z = z_true + np.random.normal(0, 2, size=x.shape)  # 노이즈 포함

# (2) 디자인 행렬: [x, y, 1]
X = np.vstack([x, y, np.ones(len(x))]).T

# (3) 최소자승 해
theta = np.linalg.inv(X.T @ X) @ (X.T @ z)
a, b, c = theta
print(f"추정된 평면: z = {a:.2f}x + {b:.2f}y + {c:.2f}")

# (4) 피팅 평면 계산
xx, yy = np.meshgrid(np.linspace(0,10,10), np.linspace(0,10,10))
zz = a*xx + b*yy + c

# (5) 시각화
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection="3d")

# 데이터 점
ax.scatter(x, y, z, color="red", label="data(exp)")
# 실제 평면 (노이즈 없는 데이터)
ax.plot_trisurf(x, y, z_true, alpha=0.2, color="blue", label="actual plane")
# 최소자승 평면
ax.plot_surface(xx, yy, zz, alpha=0.5, color="green")

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.set_title("3D Least Squares: data → projection to plane")
plt.legend()
plt.show()
# Out:
# 추정된 평면: z = 2.04x + 3.20y + 3.24
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# $$
# \begin{bmatrix}
# \sum_i^nx_i^2 & \sum_i^nx_i\\
# \sum_i^nx_i & n
# \end{bmatrix}
# \begin{bmatrix}
# \tilde a\\
# \tilde b
# \end{bmatrix}
# =
# \begin{bmatrix}
# \sum_i^nx_iy_i\\
# \sum_i^ny_i
# \end{bmatrix}
# $$
